# %%
# %pip install --upgrade langchain langchain-community langgraph openai langchain_openai
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 26.1.2 is available.
# You should consider upgrading via the 'c:\Users\HP\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
# %pip uninstall wikipedia -y
# Out:
# Found existing installation: wikipedia 1.4.0
# Uninstalling wikipedia-1.4.0:
#   Successfully uninstalled wikipedia-1.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install wikipedia-api
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 26.1.2 is available.
# You should consider upgrading via the 'c:\Users\HP\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
# %pip install -U wikipedia
# Out:
# ...
#   Using cached wikipedia-1.4.0.tar.gz (27 kB)
# ...
# Using legacy 'setup.py install' for wikipedia, since package 'wheel' is not installed.
# ...
#     Running setup.py install for wikipedia: started
#     Running setup.py install for wikipedia: finished with status 'done'
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 26.1.2 is available.
# You should consider upgrading via the 'c:\Users\HP\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
from langchain_core.tools import Tool
import requests

def wikipedia_search(query: str):
    url = "https://en.wikipedia.org/w/api.php"

    params = {
        "action": "query",
        "list": "search",
        "srsearch": query,
        "format": "json",
    }

    headers = {
        "User-Agent": "LangChainAgent/1.0"
    }

    response = requests.get(
        url,
        params=params,
        headers=headers
    )

    data = response.json()

    results = data["query"]["search"]

    if not results:
        return "No Wikipedia results found."

    return results[0]["snippet"]


wiki_tool = Tool(
    name="wikipedia_search",
    func=wikipedia_search,
    description="Search Wikipedia for factual information."
)

# %%
import requests

headers = {
    "User-Agent": "MyWikipediaApp/1.0 (siddhartha_borpuzari@rediffmail.com)"
}

params = {
    "action": "query",
    "list": "search",
    "srsearch": "AI agents",
    "format": "json"
}

r = requests.get(
    "https://en.wikipedia.org/w/api.php",
    headers=headers,
    params=params,
    timeout=10
)

print(r.status_code)
print(r.text[:300])
# Out:
# 200
# {"batchcomplete":"","continue":{"sroffset":10,"continue":"-||"},"query":{"searchinfo":{"totalhits":11387,"suggestion":"a.i agents","suggestionsnippet":"a.i agents"},"search":[{"ns":0,"title":"AI agent","pageid":78823217,"size":78570,"wordcount":6545,"snippet":"artificial intelligence, <span class=\"

# %%
wiki_tool.run({"query": "Pyspark"})
# Out:
# 'clusters from <span class="searchmatch">PySpark</span> applications. A typical <span class="searchmatch">PySpark</span> program uses a SparkSession to load data as a DataFrame and apply transformations: from <span class="searchmatch">pyspark</span>.sql import'

# %%
import os 
# %pip install python-dotenv
api_key = os.environ["api_key"]
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 26.1.2 is available.
# You should consider upgrading via the 'c:\Users\HP\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(temperature=0, api_key=api_key, model="gpt-4o-mini")

# %%
tools = [wiki_tool]

# Tool binding
llm_with_tools = llm.bind_tools(tools)

#Tool calling
result = llm_with_tools.invoke("Hello world!")

# %%
result
# Out:
# AIMessage(content='Hello! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 53, 'total_tokens': 63, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_844ddd95ff', 'id': 'chatcmpl-E0JRNM9uLLOR8qf1QrfRKrhGZwYnS', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f4f64-f2ff-7430-8a3c-50145fe08601-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 53, 'output_tokens': 10, 'total_tokens': 63, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
result.content
# Out:
# 'Hello! How can I assist you today?'

# %%
# %pip show langgraph
# Out:
# Name: langgraph
# Version: 1.2.9
# Summary: Building stateful, multi-actor applications with LLMs
# Home-page:
# Author:
# Author-email:
# License:
# Location: c:\users\hp\appdata\local\programs\python\python310\lib\site-packages
# Requires: xxhash, langgraph-sdk, langgraph-prebuilt, pydantic, langchain-core, langgraph-checkpoint
# Required-by: langchain
# Note: you may need to restart the kernel to use updated packages.

# %%
import langchain
print(langchain.__version__)
# Out:
# 1.3.13

# %%
from langchain.agents import create_agent

agent = create_agent(
    model=llm,
    tools=tools,
    system_prompt="You are a helpful assistant."
)

# %%
from langchain_core.messages import HumanMessage

response = agent.invoke({"messages": [HumanMessage(content="hi!")]})

response["messages"]
# Out:
# [HumanMessage(content='hi!', additional_kwargs={}, response_metadata={}, id='14616114-b6f6-4647-add7-e6be22599b43'),
# ...

# %%
print(response["messages"][-1].content)
# Out:
# Hello! How can I assist you today?

# %%
import wikipedia

print(wikipedia.search("Azure data factory"))
# Out:
# ['Microsoft Azure', 'Power Query', 'Bentley Azure', 'Bentley Bentayga', 'Microsoft', 'Oracle Database', 'MindSphere', 'Marvell Technology', 'Bata Corporation', 'List of Microsoft software']

# %%
from langchain_core.messages import HumanMessage

response = agent.invoke({"messages": [HumanMessage(content="what is SQL ?")]})

response["messages"]
# Out:
# [HumanMessage(content='what is SQL ?', additional_kwargs={}, response_metadata={}, id='085136ca-0e39-428e-8755-604c5f6a5d34'),
# ...

# %%
print(response["messages"][-1].content)
# Out:
# SQL, or Structured Query Language, is a domain-specific language used for managing and manipulating relational databases. It is used for tasks such as querying data, updating records, inserting new data, and deleting data from a database. SQL is widely used in various database systems, including MySQL, PostgreSQL, Microsoft SQL Server, and SQLite.
#
# SQL allows users to perform operations like creating and modifying database structures, as well as retrieving and processing data efficiently.
